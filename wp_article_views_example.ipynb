# %% [markdown]
# # Article Page Views API Example
# This example illustrates how to access page view data using the [Wikimedia REST API](https://www.mediawiki.org/wiki/Wikimedia_REST_API). This example shows how to request monthly counts of page views for one specific article. The API documentation, [pageviews/per-article](https://wikimedia.org/api/rest_v1/#/Pageviews%20data), covers additional details that may be helpful when trying to use or understand this example.
#
# ## License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.1 - May 5, 2022

# %%
# 
# These are standard python modules
import json, time, urllib.parse
#
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests

import pandas as pd

# %%
#Get the list of dinosaur names from the csv

df = pd.read_csv("dinosaur_genera.cleaned.SEPT.2022 - dinosaur_genera.cleaned.SEPT.2022.csv")
# ' '.join(df['name'].tolist())

# %%
#########
#
#    CONSTANTS
#

# The REST API 'pageviews' URL - this is the common URL/endpoint for all 'pageviews' API requests
API_REQUEST_PAGEVIEWS_ENDPOINT = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/'

# This is a parameterized string that specifies what kind of pageviews request we are going to make
# In this case it will be a 'per-article' based request. The string is a format string so that we can
# replace each parameter with an appropriate value before making the request
API_REQUEST_PER_ARTICLE_PARAMS = 'per-article/{project}/{access}/{agent}/{article}/{granularity}/{start}/{end}'

# The Pageviews API asks that we not exceed 100 requests per second, we add a small delay to each request
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making a request to the Wikimedia API they ask that you include a "unique ID" that will allow them to
# contact you if something happens - such as - your code exceeding request limits - or some other error happens
REQUEST_HEADERS = {
    'User-Agent': '<yangj98@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2022',
}

df = pd.read_csv("dinosaur_genera.cleaned.SEPT.2022 - dinosaur_genera.cleaned.SEPT.2022.csv")
ARTICLE_TITLES = df['name']

# This is just a list of English Wikipedia article titles that we can use for example requests
# ARTICLE_TITLES = [ 'Bison', 'Northern flicker', 'Red squirrel', 'Chinook salmon', 'Horseshoe bat' ]

# This template is used to map parameter values into the API_REQUST_PER_ARTICLE_PARAMS portion of an API request. The dictionary has a
# field/key for each of the required parameters. In the example, below, we only vary the article name, so the majority of the fields
# can stay constant for each request. Of course, these values *could* be changed if necessary.
ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE = {
    "project":     "en.wikipedia.org",
    "access":      "mobile",      # this should be changed for the different access types
    "agent":       "user",
    "article":     "",             # this value will be set/changed before each request
    "granularity": "monthly",
    "start":       "2015010100",
    "end":         "2022093000"    # this is likely the wrong end date
}

# %%
print(ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE)
# Out:
# {'project': 'en.wikipedia.org', 'access': 'mobile', 'agent': 'user', 'article': '', 'granularity': 'monthly', 'start': '2015010100', 'end': '2022093000'}

# %% [markdown]
# The example relies on some constants that help make the code a bit more readable.

# %% [markdown]
# The API request will be made using one procedure. The idea is to make this reusable. The procedure is parameterized, but relies on the constants above for the important parameters. The underlying assumption is that this will be used to request data for a set of article pages. Therefore the parameter most likely to change is the article_title.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageviews_per_article(article_title = None, 
                                  endpoint_url = API_REQUEST_PAGEVIEWS_ENDPOINT, 
                                  endpoint_params = API_REQUEST_PER_ARTICLE_PARAMS, 
                                  request_template = ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE,
                                  headers = REQUEST_HEADERS):
    # Make sure we have an article title
    if not article_title: return None
    
    # Titles are supposed to have spaces replaced with "_" and be URL encoded
    article_title_encoded = urllib.parse.quote(article_title.replace(' ','_'))
    request_template['article'] = article_title_encoded
    
    # now, create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_params.format(**request_template)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
# print("Getting pageview data for: ",ARTICLE_TITLES)
views = {}
for article in ARTICLE_TITLES:
    views[article] = request_pageviews_per_article(article)
    print(article, " done!")
# Out:
# “Coelosaurus” antiquus  done!
# Aachenosaurus  done!
# Aardonyx  done!
# Abdarainurus  done!
# Abditosaurus  done!
# Abelisaurus  done!
# Abrictosaurus  done!
# Abrosaurus  done!
# Abydosaurus  done!
# Acantholipan  done!
# Acanthopholis  done!
# Achelousaurus  done!
# Acheroraptor  done!
# Achillesaurus  done!
# Achillobator  done!
# Acristavus  done!
# Acrocanthosaurus  done!
# Acrotholus  done!
# Actiosaurus  done!
# Adamantisaurus  done!
# Adasaurus  done!
# Adelolophus  done!
# Adeopapposaurus  done!
# Adratiklit  done!
# Adynomosaurus  done!
# Aegyptosaurus  done!
# Aeolosaurus  done!
# Aepisaurus  done!
# Aepyornithomimus  done!
# Aerosteon  done!
# Afromimus  done!
# Afrovenator  done!
# Agathaumas  done!
# Aggiosaurus  done!
# Agilisaurus  done!
# Agnosphitys  done!
# Agrosaurus  done!
# Agujaceratops  done!
# Agustinia  done!
# Ahshislepelta  done!
# Ajkaceratops  done!
# Ajnabia  done!
# Akainacephalus  done!
# Alamosaurus  done!
# Alaskacephale  done!
# Albalophosaurus  done!
# Albertaceratops  done!
# Albertadromeus  done!
# Albertavenator  done!
# Albertonykus  done!
# Albertosaurus  done!
# Albinykus  done!
# Albisaurus  done!
# Alcovasaurus  done!
# Alectrosaurus  done!
# Aletopelta  done!
# Algoasaurus  done!
# Alioramus  done!
# Allosaurus  done!
# Almas ukhaa  done!
# Alnashetri  done!
# Alocodon  done!
# Altirhinus  done!
# Altispinax  done!
# Alvarezsaurus  done!
# Alwalkeria  done!
# Alxasaurus  done!
# Amanzia  done!
# Amargasaurus  done!
# Amargatitanis  done!
# Amazonsaurus  done!
# Ambopteryx  done!
# Ampelosaurus  done!
# Amphicoelias  done!
# Amtocephale  done!
# Amtosaurus  done!
# Amurosaurus  done!
# Amygdalodon  done!
# Anabisetia  done!
# Analong  done!
# Anasazisaurus  done!
# Anchiceratops  done!
# Anchiornis  done!
# Anchisaurus  done!
# Andesaurus  done!
# Angolatitan  done!
# Angulomastacator  done!
# Anhuilong  done!
# Aniksosaurus  done!
# Animantarx  done!
# Ankistrodon  done!
# Ankylosauria  done!
# Ankylosaurus  done!
# Anodontosaurus  done!
# Anomalipes  done!
# Anoplosaurus  done!
# Anserimimus  done!
# Antarctopelta  done!
# Antarctosaurus  done!
# Antetonitrus  done!
# Antrodemus  done!
# Anzu wyliei  done!
# Aoniraptor  done!
# Aorun  done!
# Apatodon  done!
# Apatoraptor  done!
# Apatosaurus  done!
# Appalachiosaurus  done!
# Aquilarhinus  done!
# Aquilops  done!
# Arackar  done!
# Aragosaurus  done!
# Aralosaurus  done!
# Aratasaurus  done!
# Archaeoceratops  done!
# Archaeodontosaurus  done!
# Archaeopteryx  done!
# Archaeoraptor  done!
# Archaeornithoides  done!
# Archaeornithomimus  done!
# Archosaur  done!
# Arcovenator  done!
# Arctosaurus  done!
# Arcusaurus  done!
# Arenysaurus  done!
# Argentinosaurus  done!
# Argyrosaurus  done!
# Aristosuchus  done!
# Arizonasaurus  done!
# Arkansaurus  done!
# Arkharavia  done!
# Arrhinoceratops  done!
# Arrudatitan  done!
# Arstanosaurus  done!
# Asfaltovenator  done!
# Asiaceratops  done!
# Asiamericana  done!
# Asiatosaurus  done!
# Asilisaurus  done!
# Astrodon  done!
# Astrophocaudia  done!
# Asylosaurus  done!
# Atacamatitan  done!
# Atlantosaurus  done!
# Atlasaurus  done!
# Atlascopcosaurus  done!
# Atrociraptor  done!
# Atsinganosaurus  done!
# Aublysodon  done!
# Aucasaurus  done!
# Augustynolophus  done!
# Auroraceratops  done!
# Aurornis  done!
# Australodocus  done!
# Australotitan  done!
# Australovenator  done!
# Austrocheirus  done!
# Austroposeidon  done!
# Austroraptor  done!
# Austrosaurus  done!
# Avaceratops  done!
# Avalonianus  done!
# Avebrevicauda  done!
# Avemetatarsalia  done!
# Aviatyrannis  done!
# Avimimus  done!
# Avipes  done!
# Avisaurus  done!
# Azendohsaurus  done!
# Azhdarchoidea  done!
# Baalsaurus  done!
# Bactrosaurus  done!
# Bagaceratops  done!
# Bagaraatan  done!
# Bagualia  done!
# Bagualosaurus  done!
# Bahariasaurus  done!
# Bainoceratops  done!
# Bajadasaurus  done!
# Balaur bondoc  done!
# Bambiraptor  done!
# Banji  done!
# Bannykus  done!
# Baotianmansaurus  done!
# Barapasaurus  done!
# Barilium  done!
# Barosaurus  done!
# Barrosasaurus  done!
# Barsboldia  done!
# Baryonyx  done!
# Bashanosaurus  done!
# Basutodon  done!
# Batyrosaurus  done!
# Baurutitan  done!
# Bayannurosaurus  done!
# Beg tse  done!
# Beibeilong  done!
# Beipiaognathus  done!
# Beipiaosaurus  done!
# Beishanlong  done!
# Bellusaurus  done!
# Belodon  done!
# Berberosaurus  done!
# Berthasaura  done!
# Betasuchus  done!
# Bicentenaria  done!
# Bienosaurus  done!
# Bissektipelta  done!
# Bistahieversor  done!
# Bisticeratops  done!
# Blasisaurus  done!
# Blikanasaurus  done!
# Bolong  done!
# Bonapartenykus  done!
# Bonapartesaurus  done!
# Bonatitan  done!
# Bonitasaura  done!
# Borealopelta  done!
# Borealosaurus  done!
# Boreonykus  done!
# Borogovia  done!
# Bothriospondylus  done!
# Brachiosaurus  done!
# Brachyceratops  done!
# Brachylophosaurus  done!
# Brachypodosaurus  done!
# Brachytrachelopan  done!
# Bradycneme  done!
# Brasileosaurus  done!
# Brasilotitan  done!
# Bravasaurus  done!
# Bravoceratops  done!
# Breviceratops  done!
# Brighstoneus  done!
# Brithopus  done!
# Brohisaurus  done!
# Brontomerus  done!
# Brontosaurus  done!
# Bruhathkayosaurus  done!
# Buitreraptor  done!
# Burianosaurus  done!
# Buriolestes  done!
# Byronosaurus  done!
# Caenagnathasia  done!
# Caenagnathus  done!
# Caihong  done!
# Calamosaurus  done!
# Calamospondylus  done!
# Callovosaurus  done!
# Camarasaurus  done!
# Camarillasaurus  done!
# Camelotia  done!
# Camposaurus  done!
# Camptosaurus  done!
# Campylodoniscus  done!
# Canardia  done!
# Carcharodontosaurus  done!
# Cardiodon  done!
# Carnotaurus  done!
# Caseosaurus  done!
# Cathartesaura  done!
# Caudipteryx  done!
# Cedarosaurus  done!
# Cedarpelta  done!
# Cedrorestes  done!
# Centemodon  done!
# Centrosaurus  done!
# Cerasinops  done!
# Ceratonykus  done!
# Ceratops  done!
# Ceratosaurus  done!
# Ceratosuchops  done!
# Cetiosauriscus  done!
# Cetiosaurus  done!
# Changchunsaurus  done!
# Changmiania  done!
# Changyuraptor  done!
# Chaoyangsaurus  done!
# Charonosaurus  done!
# Chasmosaurus  done!
# Chebsaurus  done!
# Chenanisaurus  done!
# Chialingosaurus  done!
# Chiayusaurus  done!
# Chienkosaurus  done!
# Chilantaisaurus  done!
# Chilesaurus  done!
# Chindesaurus  done!
# Chingkankousaurus  done!
# Chinshakiangosaurus  done!
# Chirostenotes  done!
# Choconsaurus  done!
# Chondrosteosaurus  done!
# Choyrodon  done!
# Chromogisaurus  done!
# Chuandongocoelurus  done!
# Chuanjiesaurus  done!
# Chuanqilong  done!
# Chubutisaurus  done!
# Chungkingosaurus  done!
# Chuxiongosaurus  done!
# Cionodon  done!
# Citipati  done!
# Citipes  done!
# Claorhynchus  done!
# Claosaurus  done!
# Clasmodosaurus  done!
# Clepsysaurus  done!
# Coahuilaceratops  done!
# Coelophysis  done!
# Coeluroides  done!
# Coelurosauravus  done!
# Coelurus  done!
# Colepiocephale  done!
# Coloradisaurus  done!
# Comahuesaurus  done!
# Compsognathus  done!
# Compsosuchus  done!
# Concavenator  done!
# Conchoraptor  done!
# Condorraptor  done!
# Convolosaurus  done!
# Coronosaurus  done!
# Corythoraptor  done!
# Corythosaurus  done!
# Craspedodon  done!
# Craterosaurus  done!
# Crichtonpelta  done!
# Crichtonsaurus  done!
# Cristatusaurus  done!
# Crittendenceratops  done!
# Crocodilia  done!
# Crosbysaurus  done!
# Crurotarsi  done!
# Cruxicheiros  done!
# Cryolophosaurus  done!
# Cryptosaurus  done!
# Cumnoria  done!
# Daanosaurus  done!
# Dacentrurus  done!
# Daemonosaurus  done!
# Dahalokely  done!
# Dakosaurus  done!
# Dakotadon  done!
# Dakotaraptor  done!
# Daliansaurus  done!
# Dandakosaurus  done!
# Dashanpusaurus  done!
# Daspletosaurus  done!
# Dasygnathoides  done!
# Datanglong  done!
# Datonglong  done!
# Datousaurus  done!
# Daxiatitan  done!
# Deinocheirus  done!
# Deinodon  done!
# Deinonychus  done!
# Deltadromeus  done!
# Demandasaurus  done!
# Denversaurus  done!
# Deuterosaurus  done!
# Diabloceratops  done!
# Diamantinasaurus  done!
# Dianchungosaurus  done!
# Diapsid  done!
# Diclonius  done!
# Dicraeosaurus  done!
# Dilong paradoxus  done!
# Dilophosaurus  done!
# Diluvicursor  done!
# Dimetrodon  done!
# Dineobellator  done!
# Dinheirosaurus  done!
# Dinodocus  done!
# Diplodocus  done!
# Diplotomodon  done!
# Dolichosuchus  done!
# Dongbeititan  done!
# Dongyangopelta  done!
# Dongyangosaurus  done!
# Doratodon  done!
# Draconyx  done!
# Dracopelta  done!
# Dracoraptor  done!
# Dracovenator  done!
# Dravidosaurus  done!
# Dreadnoughtus  done!
# Dromaeosauroides  done!
# Dromaeosaurus  done!
# Dromiceiomimus  done!
# Drusilasaura  done!
# Dryosaurus  done!
# Dryptosauroides  done!
# Dryptosaurus  done!
# Dubreuillosaurus  done!
# Duriatitan  done!
# Duriavenator  done!
# Dynamoterror  done!
# Dyoplosaurus  done!
# Dysalotosaurus  done!
# Dysganus  done!
# Dyslocosaurus  done!
# Dystrophaeus  done!
# Dzharaonyx  done!
# Dzharatitanis  done!
# Echinodon  done!
# Edmontonia  done!
# Edmontosaurus  done!
# Efraasia  done!
# Einiosaurus  done!
# Ekrixinatosaurus  done!
# Elachistosuchus  done!
# Elaltitan  done!
# Elaphrosaurus  done!
# Elemgasem  done!
# Elmisaurus  done!
# Elopteryx  done!
# Elrhazosaurus  done!
# Emausaurus  done!
# Embasaurus  done!
# Enigmosaurus  done!
# Eoabelisaurus  done!
# Eocarcharia  done!
# Eocursor  done!
# Eodromaeus  done!
# Eolambia  done!
# Eomamenchisaurus  done!
# Eoraptor  done!
# Eosinopteryx  done!
# Eotrachodon  done!
# Eotriceratops  done!
# Eotyrannus  done!
# Eousdryosaurus  done!
# Epachthosaurus  done!
# Epanterias  done!
# Epichirostenotes  done!
# Epidexipteryx  done!
# Equijubus  done!
# Erectopus  done!
# Erketu  done!
# Erliansaurus  done!
# Erlikosaurus  done!
# Erythrovenator  done!
# Eshanosaurus  done!
# Eucamerotus  done!
# Eucercosaurus  done!
# Eucnemesaurus  done!
# Eucoelophysis  done!
# Euhelopus  done!
# Euoplocephalus  done!
# Eurolimnornis  done!
# Euronychodon  done!
# Europasaurus  done!
# Europatitan  done!
# Europelta  done!
# Euskelosaurus  done!
# Eustreptospondylus  done!
# Fabrosaurus  done!
# Falcarius  done!
# Ferganasaurus  done!
# Ferganocephale  done!
# Ferrisaurus  done!
# Foraminacephale  done!
# Fosterovenator  done!
# Fostoria dhimbangunmal  done!
# Fruitadens  done!
# Fukuiraptor  done!
# Fukuisaurus  done!
# Fukuititan  done!
# Fukuivenator  done!
# Fulengia  done!
# Fulgurotherium  done!
# Fushanosaurus  done!
# Fusuisaurus  done!
# Futabasaurus  done!
# Futalognkosaurus  done!
# Fylax  done!
# Galeamopus  done!
# Galesaurus  done!
# Galleonosaurus  done!
# Gallimimus  done!
# Galvesaurus  done!
# Gannansaurus  done!
# Ganzhousaurus  done!
# Gargoyleosaurus  done!
# Garrigatitan  done!
# Garudimimus  done!
# Gasosaurus  done!
# Gasparinisaura  done!
# Gastonia (dinosaur)  done!
# Geminiraptor  done!
# Genusaurus  done!
# Genyodectes  done!
# Geosaurus  done!
# Geranosaurus  done!
# Gideonmantellia  done!
# Giganotosaurus  done!
# Gigantoraptor  done!
# Gigantosaurus  done!
# Gigantoscelus  done!
# Gigantspinosaurus  done!
# Gilmoreosaurus  done!
# Giraffatitan  done!
# Glacialisaurus  done!
# Glishades  done!
# Glyptodontopelta  done!
# Gnathovorax  done!
# Gobihadros  done!
# Gobiraptor  done!
# Gobisaurus  done!
# Gobititan  done!
# Gobivenator  done!
# Gojirasaurus  done!
# Gondwanatitan  done!
# Gongbusaurus  done!
# Gongpoquansaurus  done!
# Gongxianosaurus  done!
# Gorgosaurus  done!
# Goyocephale  done!
# Graciliceratops  done!
# Graciliraptor  done!
# Gracilisuchus  done!
# Gravitholus  done!
# Gresslyosaurus  done!
# Gryphoceratops  done!
# Gryponyx  done!
# Gryposaurus  done!
# Guaibasaurus  done!
# Gualicho  done!
# Guanlong  done!
# Guemesia  done!
# Gwyneddosaurus  done!
# Gyposaurus  done!
# Hadrosaurus  done!
# Haestasaurus  done!
# Hagryphus  done!
# Hallopus  done!
# Halszkaraptor  done!
# Halticosaurus  done!
# Hamititan  done!
# Hanssuesia  done!
# Haplocanthosaurus  done!
# Haplocheirus  done!
# Harpymimus  done!
# Haya griva  done!
# Heishansaurus  done!
# Helioceratops  done!
# Heptasteornis  done!
# Herbstosaurus  done!
# Herrerasaurus  done!
# Hesperonychus  done!
# Hesperornithoides  done!
# Hesperosaurus  done!
# Heterodontosaurus  done!
# Hexing  done!
# Hexinlusaurus  done!
# Heyuannia  done!
# Hierosaurus  done!
# Hippodraco  done!
# Histriasaurus  done!
# Homalocephale  done!
# Honghesaurus  done!
# Hoplitosaurus  done!
# Horshamosaurus  done!
# Hortalotarsus  done!
# Huabeisaurus  done!
# Hualianceratops  done!
# Huallasaurus  done!
# Huanansaurus  done!
# Huanghetitan  done!
# Huangshanlong  done!
# Huaxiagnathus  done!
# Huayangosaurus  done!
# Hudiesaurus  done!
# Huehuecanauhtlus  done!
# Huinculsaurus  done!
# Hulsanpes  done!
# Hungarosaurus  done!
# Hylaeosaurus  done!
# Hypacrosaurus  done!
# Hyperodapedon  done!
# Hypselorhachis  done!
# Hypselosaurus  done!
# Hypselospinus  done!
# Hypsibema  done!
# Hypsibema missouriensis  done!
# Hypsilophodon  done!
# Hypsirhophus  done!
# Iberospinus  done!
# Ichthyosaur  done!
# Ichthyovenator  done!
# Ignavusaurus  done!
# Ignotosaurus  done!
# Iguanacolossus  done!
# Iguanodon  done!
# Iliosuchus  done!
# Ilokelesia  done!
# Imperobator  done!
# Incisivosaurus  done!
# Indosaurus  done!
# Indosuchus  done!
# Ingentia  done!
# Inosaurus  done!
# Invictarx  done!
# Irisosaurus  done!
# Irritator  done!
# Isaberrysaura  done!
# Isanosaurus  done!
# Isasicursor  done!
# Ischioceratops  done!
# Isisaurus  done!
# Issi  done!
# Itapeuasaurus  done!
# Itemirus  done!
# Iuticosaurus  done!
# Iyuku  done!
# Jainosaurus  done!
# Jakapil  done!
# Jaklapallisaurus  done!
# Janenschia  done!
# Jaxartosaurus  done!
# Jeholosaurus  done!
# Jeyawati  done!
# Jianchangosaurus  done!
# Jiangjunosaurus  done!
# Jiangshanosaurus  done!
# Jiangxisaurus  done!
# Jianianhualong  done!
# Jinbeisaurus  done!
# Jinfengopteryx  done!
# Jingshanosaurus  done!
# Jintasaurus  done!
# Jinyunpelta  done!
# Jinzhousaurus  done!
# Jiutaisaurus  done!
# Jobaria  done!
# Jubbulpuria  done!
# Judiceratops  done!
# Juratyrant  done!
# Juravenator  done!
# Kaatedocus  done!
# Kaijiangosaurus  done!
# Kaijutitan  done!
# Kakuru  done!
# Kamuysaurus  done!
# Kangnasaurus  done!
# Kansaignathus  done!
# Karongasaurus  done!
# Katepensaurus  done!
# Kayentavenator  done!
# Kazaklambia  done!
# Kelmayisaurus  done!
# Kelumapusaura  done!
# Kemkemia  done!
# Kentrosaurus  done!
# Kerberosaurus  done!
# Khaan  done!
# Kholumolumo  done!
# Khulsanurus  done!
# Kileskus  done!
# Kinnareemimus  done!
# Klamelisaurus  done!
# Kol ghuva  done!
# Koparion  done!
# Koreaceratops  done!
# Koreanosaurus  done!
# Koshisaurus  done!
# Kosmoceratops  done!
# Kotasaurus  done!
# Koutalisaurus  done!
# Kritosaurus  done!
# Kryptops  done!
# Krzyzanowskisaurus  done!
# Kulceratops  done!
# Kulindadromeus  done!
# Kunbarrasaurus  done!
# Kundurosaurus  done!
# Kuru kulla  done!
# Kurupi itaata  done!
# Kuszholia  done!
# Kwanasaurus  done!
# Labocania  done!
# Laevisuchus  done!
# Lagerpeton  done!
# Lagosuchus  done!
# Laiyangosaurus  done!
# Lajasvenator  done!
# Lambeosaurus  done!
# Lametasaurus  done!
# Lamplughsaura  done!
# Lanzhousaurus  done!
# Laosaurus  done!
# Lapampasaurus  done!
# Laplatasaurus  done!
# Lapparentosaurus  done!
# Laquintasaura  done!
# Lariosaurus  done!
# Latenivenatrix  done!
# Latirhinus  done!
# Lavocatisaurus  done!
# Leaellynasaura  done!
# Ledumahadi  done!
# Leinkupal  done!
# Leonerasaurus  done!
# Lepidus praecisio  done!
# Leptoceratops  done!
# Leshansaurus  done!
# Lesothosaurus  done!
# Lessemsaurus  done!
# Levnesovia  done!
# Lewisuchus  done!
# Lexovisaurus  done!
# Leyesaurus  done!
# Liaoceratops  done!
# Liaoningosaurus  done!
# Liaoningotitan  done!
# Liaoningvenator  done!
# Libycosaurus  done!
# Ligabueino  done!
# Ligabuesaurus  done!
# Liliensternus  done!
# Limaysaurus  done!
# Limusaurus  done!
# Lingwulong  done!
# Lingyuanosaurus  done!
# Linhenykus  done!
# Linheraptor  done!
# Linhevenator  done!
# Lirainosaurus  done!
# Lisboasaurus  done!
# Liubangosaurus  done!
# Llukalkan  done!
# Lohuecotitan  done!
# Loncosaurus  done!
# Longisquama  done!
# Lophorhothon  done!
# Lophostropheus  done!
# Lophotrochozoa  done!
# Loricatosaurus  done!
# Loricosaurus  done!
# Losillasaurus  done!
# Lourinhanosaurus  done!
# Lourinhasaurus  done!
# Luanchuanraptor  done!
# Lucianosaurus  done!
# Lucianovenator  done!
# Lufengosaurus  done!
# Lukousaurus  done!
# Luoyanggia  done!
# Lurdusaurus  done!
# Lusitanosaurus  done!
# Lusotitan  done!
# Lusovenator  done!
# Lutungutali  done!
# Lycorhinus  done!
# Lythronax  done!
# Macelognathus  done!
# Machairasaurus  done!
# Machairoceratops  done!
# Machimosaurus  done!
# Macrocollum  done!
# Macrodontophion  done!
# Macrogryphosaurus  done!
# Macrurosaurus  done!
# Magnamanus  done!
# Magnapaulia  done!
# Magnosaurus  done!
# Magyarosaurus  done!
# Mahakala omnogovae  done!
# Mahuidacursor  done!
# Maiasaura  done!
# Maip  done!
# Majungasaurus  done!
# Malarguesaurus  done!
# Malawisaurus  done!
# Maleevus  done!
# Mamenchisaurus  done!
# Mandschurosaurus  done!
# Manidens  done!
# Mansourasaurus  done!
# Mantellisaurus  done!
# Mapusaurus  done!
# Maraapunisaurus  done!
# Marasuchus  done!
# Marmarospondylus  done!
# Marshosaurus  done!
# Martharaptor  done!
# Masiakasaurus  done!
# Massospondylus  done!
# Matheronodon  done!
# Maxakalisaurus  done!
# Mbiresaurus  done!
# Medusaceratops  done!
# Megalosaurus  done!
# Megapnosaurus  done!
# Megaraptor  done!
# Melanorosaurus  done!
# Mendozasaurus  done!
# Menefeeceratops  done!
# Menucocelsior  done!
# Mercuriceratops  done!
# Meroktenos  done!
# Metriacanthosaurus  done!
# Microceratus  done!
# Microcoelus  done!
# Microhadrosaurus  done!
# Micropachycephalosaurus  done!
# Microraptor  done!
# Microvenator  done!
# Mierasaurus  done!
# Minmi paravertebra  done!
# Minotaurasaurus  done!
# Miragaia longicollum  done!
# Mirischia  done!
# Mnyamawamtuka  done!
# Moabosaurus  done!
# Mochlodon  done!
# Mongolosaurus  done!
# Mongolostegus  done!
# Monkonosaurus  done!
# Monoclonius  done!
# Monolophosaurus  done!
# Mononykus  done!
# Montanoceratops  done!
# Morelladon  done!
# Morinosaurus  done!
# Moros intrepidus  done!
# Morrosaurus  done!
# Mosaiceratops  done!
# Mosasaur  done!
# Murusraptor  done!
# Mussaurus  done!
# Muttaburrasaurus  done!
# Muyelensaurus  done!
# Mymoorapelta  done!
# Naashoibitosaurus  done!
# Nambalia  done!
# Nankangia  done!
# Nanningosaurus  done!
# Nanosaurus  done!
# Nanshiungosaurus  done!
# Nanuqsaurus  done!
# Nanyangosaurus  done!
# Napaisaurus  done!
# Narambuenatitan  done!
# Narindasaurus  done!
# Nasutoceratops  done!
# Navajoceratops  done!
# Nebulasaurus  done!
# Nedcolbertia  done!
# Nedoceratops  done!
# Neimongosaurus  done!
# Nemegtomaia  done!
# Nemegtonykus  done!
# Nemegtosaurus  done!
# Neosodon  done!
# Neovenator  done!
# Neuquenraptor  done!
# Neuquensaurus  done!
# Ngwevu  done!
# Nhandumirim  done!
# Niebla antiqua  done!
# Nigersaurus  done!
# Ningyuansaurus  done!
# Ninjatitan  done!
# Niobrarasaurus  done!
# Nipponosaurus  done!
# Noasaurus  done!
# Nodocephalosaurus  done!
# Nodosaurus  done!
# Nomingia  done!
# Nopcsaspondylus  done!
# Normanniasaurus  done!
# Notatesseraeraptor  done!
# Nothosaur  done!
# Nothronychus  done!
# Notoceratops  done!
# Notocolossus  done!
# Notohypsilophodon  done!
# Nqwebasaurus  done!
# Nullotitan  done!
# Nuthetes  done!
# Nyasasaurus  done!
# Oceanotitan  done!
# Ohmdenosaurus  done!
# Ojoceratops  done!
# Ojoraptorsaurus  done!
# Oksoko avarsan  done!
# Oligosaurus  done!
# Olorotitan  done!
# Omeisaurus  done!
# Ondogurvel  done!
# Oohkotokia  done!
# Opisthocoelicaudia  done!
# Oplosaurus  done!
# Orkoraptor  done!
# Ornatops  done!
# Ornithodesmus  done!
# Ornitholestes  done!
# Ornithomerus  done!
# Ornithomimoides  done!
# Ornithomimus  done!
# Ornithopsis  done!
# Ornithosuchus  done!
# Orodromeus  done!
# Orosaurus  done!
# Orthogoniosaurus  done!
# Orthomerus  done!
# Oryctodromeus  done!
# Osmakasaurus  done!
# Ostafrikasaurus  done!
# Ostromia  done!
# Ouranosaurus  done!
# Overoraptor  done!
# Overosaurus  done!
# Oviraptor  done!
# Owenodon  done!
# Oxalaia  done!
# Ozraptor  done!
# Pachycephalosaurus  done!
# Pachyrhinosaurus  done!
# Pachysuchus  done!
# Padillasaurus  done!
# Palaeoctonus  done!
# Palaeocursornis  done!
# Palaeopteryx  done!
# Palaeosaurus  done!
# Palaeoscincus  done!
# Paludititan  done!
# Pampadromaeus  done!
# Pamparaptor  done!
# Panamericansaurus  done!
# Pandoravenator  done!
# Panguraptor  done!
# Panoplosaurus  done!
# Panphagia  done!
# Pantydraco  done!
# Papiliovenator  done!
# Paralitherizinosaurus  done!
# Paralititan  done!
# Paranthodon  done!
# Pararhabdodon  done!
# Parasaurolophus  done!
# Paraxenisaurus  done!
# Pareiasaur  done!
# Pareiasaurus  done!
# Pareisactus  done!
# Parksosaurus  done!
# Paronychodon  done!
# Parvicursor  done!
# Patagonykus  done!
# Patagosaurus  done!
# Patagotitan  done!
# Pawpawsaurus  done!
# Pectinodon  done!
# Pedopenna  done!
# Pegomastax  done!
# Peishansaurus  done!
# Pelecanimimus  done!
# Pellegrinisaurus  done!
# Peloroplites  done!
# Pelorosaurus  done!
# Pelycosaur  done!
# Pendraig  done!
# Penelopognathus  done!
# Pentaceratops  done!
# Perijasaurus  done!
# Petrobrasaurus  done!
# Phaedrolosaurus  done!
# Philovenator  done!
# Phuwiangosaurus  done!
# Phuwiangvenator  done!
# Phyllodon  done!
# Phytosaur  done!
# Piatnitzkysaurus  done!
# Picrodon  done!
# Pilmatueia  done!
# Pinacosaurus  done!
# Pisanosaurus  done!
# Pitekunsaurus  done!
# Piveteausaurus  done!
# Planicoxa  done!
# Plateosauravus  done!
# Plateosaurus  done!
# Platypelta  done!
# Plesiohadros  done!
# Plesiosaur  done!
# Pneumatoarthrus  done!
# Pneumatoraptor  done!
# Podokesaurus  done!
# Poekilopleuron  done!
# Polacanthoides  done!
# Polacanthus  done!
# Polyodontosaurus  done!
# Polyonax  done!
# Ponerosteus  done!
# Poposaurus  done!
# Portellsaurus  done!
# Postosuchus  done!
# Powellvenator  done!
# Pradhania  done!
# Prenocephale  done!
# Prenoceratops  done!
# Priconodon  done!
# Priodontognathus  done!
# Proa valdearinnoensis  done!
# Probactrosaurus  done!
# Probrachylophosaurus  done!
# Proceratosaurus  done!
# Procompsognathus  done!
# Prodeinodon  done!
# Propanoplosaurus  done!
# Prosaurolophus  done!
# Protarchaeopteryx  done!
# Protecovasaurus  done!
# Protoavis  done!
# Protoceratops  done!
# Protognathosaurus  done!
# Protohadros  done!
# Protorosauria  done!
# Protorosaurus  done!
# Pseudosuchia  done!
# Psittacosaurus  done!
# Pteropelyx  done!
# Pterosaur  done!
# Pterospondylus  done!
# Puertasaurus  done!
# Pukyongosaurus  done!
# Pulanesaura  done!
# Punatitan  done!
# Pycnonemosaurus  done!
# Pyroraptor  done!
# Qantassaurus  done!
# Qianzhousaurus  done!
# Qiaowanlong  done!
# Qijianglong  done!
# Qingxiusaurus  done!
# Qinlingosaurus  done!
# Qiupalong  done!
# Qiupanykus  done!
# Quaesitosaurus  done!
# Quetecsaurus  done!
# Quilmesaurus  done!
# Rachitrema  done!
# Rahiolisaurus  done!
# Rahonavis  done!
# Rajasaurus  done!
# Rapator  done!
# Rapetosaurus  done!
# Raptorex  done!
# Ratchasimasaurus  done!
# Rativates  done!
# Rauisuchia  done!
# Rayososaurus  done!
# Razanandrongobe  done!
# Rebbachisaurus  done!
# Regaliceratops  done!
# Regnosaurus  done!
# Revueltosaurus  done!
# Rhabdodon  done!
# Rhadinosaurus  done!
# Rhinorex  done!
# Rhoetosaurus  done!
# Rhomaleopakhus  done!
# Rhopalodon  done!
# Rhynchosaur  done!
# Riabininohadros  done!
# Richardoestesia  done!
# Rileyasuchus  done!
# Rinchenia  done!
# Rinconsaurus  done!
# Riojasaurus  done!
# Riojasuchus  done!
# Riparovenator  done!
# Rocasaurus  done!
# Ruehleia  done!
# Rugocaudia  done!
# Rugops  done!
# Rukwatitan  done!
# Ruyangosaurus  done!
# Sacisaurus  done!
# Sahaliyania  done!
# Saichania  done!
# Saltasaurus  done!
# Saltopus  done!
# Saltriovenator  done!
# Sanjuansaurus  done!
# Sanpasaurus  done!
# Santanaraptor  done!
# Sanxiasaurus  done!
# Sarahsaurus  done!
# Sarcolestes  done!
# Sarcosaurus  done!
# Sarmientosaurus  done!
# Saurolophus  done!
# Sauroniops  done!
# Sauropelta  done!
# Saurophaganax  done!
# Sauroplites  done!
# Sauroposeidon  done!
# Saurornithoides  done!
# Saurornitholestes  done!
# Savannasaurus  done!
# Scansoriopteryx  done!
# Scelidosaurus  done!
# Schleitheimia  done!
# Scipionyx  done!
# Sciurumimus  done!
# Scleromochlus  done!
# Scolosaurus  done!
# Scutellosaurus  done!
# Secernosaurus  done!
# Sefapanosaurus  done!
# Segisaurus  done!
# Segnosaurus  done!
# Seitaad  done!
# Sektensaurus  done!
# Serendipaceratops  done!
# Serikornis  done!
# Shamosaurus  done!
# Shanag  done!
# Shantungosaurus  done!
# Shanxia  done!
# Shanyangosaurus  done!
# Shaochilong  done!
# Shenzhousaurus  done!
# Shidaisaurus  done!
# Shingopana  done!
# Shishugounykus  done!
# Shixinggia  done!
# Shri devi  done!
# Shuangbaisaurus  done!
# Shuangmiaosaurus  done!
# Shunosaurus  done!
# Shuvosaurus  done!
# Shuvuuia  done!
# Siamodon  done!
# Siamosaurus  done!
# Siamotyrannus  done!
# Siamraptor  done!
# Sibirotitan  done!
# Sierraceratops  done!
# Sigilmassasaurus  done!
# Silesaurus  done!
# Siluosaurus  done!
# Silutitan  done!
# Silvisaurus  done!
# Similicaudipteryx  done!
# Sinankylosaurus  done!
# Sinocalliopteryx  done!
# Sinocephale  done!
# Sinoceratops  done!
# Sinocoelurus  done!
# Sinopliosaurus  done!
# Sinornithoides  done!
# Sinornithomimus  done!
# Sinornithosaurus  done!
# Sinosauropteryx  done!
# Sinosaurus  done!
# Sinotyrannus  done!
# Sinovenator  done!
# Sinraptor  done!
# Sinusonasus  done!
# Sirindhorna  done!
# Skorpiovenator  done!
# Smitanosaurus  done!
# Sonidosaurus  done!
# Sonorasaurus  done!
# Soriatitan  done!
# Soumyasaurus  done!
# Spectrovenator  done!
# Sphaerotholus  done!
# Sphenosaurus  done!
# Sphenosuchia  done!
# Sphenosuchus  done!
# Spiclypeus  done!
# Spicomellus  done!
# Spinophorosaurus  done!
# Spinops  done!
# Spinosaurus  done!
# Spinostropheus  done!
# Spinosuchus  done!
# Spondylosoma  done!
# Squalodon  done!
# Staurikosaurus  done!
# Stegoceras  done!
# Stegopelta  done!
# Stegosaurides  done!
# Stegosaurus  done!
# Stegouros  done!
# Stellasaurus  done!
# Stenonychosaurus  done!
# Stenopelix  done!
# Stephanosaurus  done!
# Stokesosaurus  done!
# Streptospondylus  done!
# Struthiomimus  done!
# Struthiosaurus  done!
# Styracosaurus  done!
# Succinodon  done!
# Suchomimus  done!
# Suchoprion  done!
# Suchosaurus  done!
# Supersaurus  done!
# Suskityrannus  done!
# Suuwassea  done!
# Suzhousaurus  done!
# Syngonosaurus  done!
# Szechuanosaurus  done!
# Tachiraptor  done!
# Talarurus  done!
# Talenkauen  done!
# Tamarro  done!
# Tambatitanis  done!
# Tangvayosaurus  done!
# Tanius  done!
# Taniwhasaurus  done!
# Tanycolagreus  done!
# Tanystropheidae  done!
# Tanystropheus  done!
# Tanystrosuchus  done!
# Taohelong  done!
# Tapinocephalus  done!
# Tapuiasaurus  done!
# Tarascosaurus  done!
# Tarbosaurus  done!
# Tarchia  done!
# Tastavinsaurus  done!
# Tatankacephalus  done!
# Tatankaceratops  done!
# Tataouinea  done!
# Tatisaurus  done!
# Taurovenator  done!
# Taveirosaurus  done!
# Tazoudasaurus  done!
# Technosaurus  done!
# Tecovasaurus  done!
# Tehuelchesaurus  done!
# Teinurosaurus  done!
# Teleocrater  done!
# Telmatosaurus  done!
# Tendaguria  done!
# Tengrisaurus  done!
# Tenontosaurus  done!
# Teratophoneus  done!
# Teratosaurus  done!
# Termatosaurus  done!
# Terminocavus  done!
# Tethyshadros  done!
# Texacephale  done!
# Texasetes  done!
# Thanatotheristes  done!
# Thanos simonattoi  done!
# Thecocoelurus  done!
# Thecodontosaurus  done!
# Thecospondylus  done!
# Theiophytalia  done!
# Therapsid  done!
# Therizinosaurus  done!
# Theropoda  done!
# Thescelosaurus  done!
# Thespesius  done!
# Tianchisaurus  done!
# Tianyulong  done!
# Tianyuraptor  done!
# Tianzhenosaurus  done!
# Tichosteus  done!
# Tienshanosaurus  done!
# Timimus  done!
# Timurlengia  done!
# Titanoceratops  done!
# Titanosaurus  done!
# Tlatolophus  done!
# Tochisaurus  done!
# Tonganosaurus  done!
# Tongtianlong  done!
# Tornieria  done!
# Torosaurus  done!
# Torvosaurus  done!
# Tototlmimus  done!
# Trachodon  done!
# Tralkasaurus  done!
# Tratayenia  done!
# Traukutitan  done!
# Trialestes  done!
# Triceratops  done!
# Trierarchuncus  done!
# Trigonosaurus  done!
# Trimucrodon  done!
# Trinisaura  done!
# Triunfosaurus  done!
# Troodon  done!
# Tsaagan  done!
# Tsagantegia  done!
# Tsintaosaurus  done!
# Tuebingosaurus  done!
# Tugulusaurus  done!
# Tuojiangosaurus  done!
# Turanoceratops  done!
# Turiasaurus  done!
# Tylocephale  done!
# Tyrannosaurus  done!
# Tyrannotitan  done!
# Uberabatitan  done!
# Ubirajara jubatus  done!
# Udanoceratops  done!
# Ultrasaurus  done!
# Ulughbegsaurus  done!
# Unaysaurus  done!
# Unenlagia  done!
# Unescoceratops  done!
# Unquillosaurus  done!
# Urbacodon  done!
# Utahceratops  done!
# Utahraptor  done!
# Uteodon  done!
# Vagaceratops  done!
# Vahiny  done!
# Valdoraptor  done!
# Valdosaurus  done!
# Vallibonavenatrix  done!
# Variraptor  done!
# Vayuraptor  done!
# Vectaerovenator  done!
# Vectiraptor  done!
# Velafrons  done!
# Velocipes  done!
# Velociraptor  done!
# Velocisaurus  done!
# Venaticosuchus  done!
# Venenosaurus  done!
# Vespersaurus  done!
# Veterupristisaurus  done!
# Viavenator  done!
# Volgatitan  done!
# Volkheimeria  done!
# Vouivria  done!
# Vulcanodon  done!
# Wakinosaurus  done!
# Walgettosuchus  done!
# Wamweracaudia  done!
# Wannanosaurus  done!
# Weewarrasaurus  done!
# Wellnhoferia  done!
# Wendiceratops  done!
# Wiehenvenator  done!
# Willinakaqe  done!
# Wintonotitan  done!
# Wuerhosaurus  done!
# Wulagasaurus  done!
# Wulatelong  done!
# Wulong bohaiensis  done!
# Wyleyia  done!
# Xenoceratops  done!
# Xenoposeidon  done!
# Xenotarsosaurus  done!
# Xianshanosaurus  done!
# Xiaosaurus  done!
# Xiaotingia  done!
# Xingtianosaurus  done!
# Xingxiulong  done!
# Xinjiangovenator  done!
# Xinjiangtitan  done!
# Xiongguanlong  done!
# Xixianykus  done!
# Xixiasaurus  done!
# Xixiposaurus  done!
# Xiyunykus  done!
# Xuanhanosaurus  done!
# Xuanhuaceratops  done!
# Xunmenglong  done!
# Xuwulong  done!
# Yamaceratops  done!
# Yamanasaurus  done!
# Yamatosaurus  done!
# Yandusaurus  done!
# Yangchuanosaurus  done!
# Yanornis  done!
# Yaverlandia  done!
# Yehuecauhceratops  done!
# Yi (dinosaur)  done!
# Yimenosaurus  done!
# Yingshanosaurus  done!
# Yinlong  done!
# Yixianosaurus  done!
# Yizhousaurus  done!
# Yongjinglong  done!
# Ypupiara  done!
# Yuanmousaurus  done!
# Yueosaurus  done!
# Yulong mini  done!
# Yunganglong  done!
# Yunmenglong  done!
# Yunnanosaurus  done!
# Yunyangosaurus  done!
# Yurgovuchia  done!
# Yutyrannus  done!
# Yuxisaurus  done!
# Zalmoxes  done!
# Zanclodon  done!
# Zapalasaurus  done!
# Zapsalis  done!
# Zaraapelta  done!
# Zatomus  done!
# Zby  done!
# Zephyrosaurus  done!
# Zhanghenglong  done!
# Zhejiangosaurus  done!
# Zhenyuanlong  done!
# Zhongjianosaurus  done!
# Zhongornis  done!
# Zhongyuansaurus  done!
# Zhuchengceratops  done!
# Zhuchengtitan  done!
# Zhuchengtyrannus  done!
# Ziapelta  done!
# Zigongosaurus  done!
# Zizhongosaurus  done!
# Zuniceratops  done!
# Zuolong  done!
# Zuoyunlong  done!
# Zupaysaurus  done!
# Zuul  done!

# %%
#print(json.dumps(views,indent=4))
# print("Have %d months of pageview data"%(len(views['items'])))
print(views)
# for month in views:
#     print(json.dumps(month,indent=4))
# Out:
# {'“Coelosaurus” antiquus': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/%E2%80%9CCoelosaurus%E2%80%9D_antiquus/monthly/2015010100/2022093000'}, 'Aachenosaurus': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Aachenosaurus/monthly/2015010100/2022093000'}, 'Aardonyx': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Aardonyx/monthly/2015010100/2022093000'}, 'Abdarainurus': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Abdarainurus/monthly/2015010100/2022093000'}, 'Abditosaurus': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Abditosaurus/monthly/2015010100/2022093000'}, 'Abelisaurus': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Abelisaurus/monthly/2015010100/2022093000'}, 'Abrictosaurus': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Abrictosaurus/monthly/2015010100/2022093000'}, 'Abrosaurus': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Abrosaurus/monthly/2015010100/2022093000'}, 'Abydosaurus': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Abydosaurus/monthly/2015010100/2022093000'}, 'Acantholipan': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request', 'title': 'Invalid parameters', 'method': 'get', 'detail': 'data.params.access should be equal to one of the allowed values: [all-access, desktop, mobile-app, mobile-web]', 'uri': '/wikimedia.org/v1/metrics/pageviews/per-article/en.wikipedia.org/mobile/user/Acantholipan/monthly/2015010100/2022093000'}, 'Acanthopholis': {'type': 'https://mediawiki.org/wiki/HyperSwitch/errors/bad_request' ...

# %% [markdown]
# Above output should show dictionaries with views per month

# %%
#Create the monthly desktop users

with open("dino_monthly_mobile_<start201501>-<end202209>.json", "w") as outfile:
    json.dump(views['items'], outfile)

# %%
# Out:
# None
